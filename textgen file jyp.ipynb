# %%
import os

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

from transformers import pipeline

generator = pipeline("text-generation", model = "gpt2", framework = "pt", truncation = True, repetition_penalty = 1.5)

user_input = input("Enter a prompt for text generation:\n")

max_len = int(input("Enter the maximum length of generated text:\n"))

result = generator(user_input, max_length = max_len, num_return_sequences = 1)

print("Generated text is:\n")
print(result[0]["generated_text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Enter a prompt for text generation:
# Once upon a time in a futuristic city
# Enter the maximum length of generated text:
# 100
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated text is:
#
# Once upon a time in a futuristic city, the world will be consumed by battle machines. As you play through this game of doom there are some fantastic moments with lots and tons to explore as well such as:
# 1) The player must run from one enemy machine (or ship), so that they can survive until it's completed or else die trying; 2-3 times during your turn when an opening is unlocked before another opens up for both yourself — see below if these two situations match "lucky" conditions! 3-) There may even happen random bosses being pushed over obstacles along their path using clever AI tactics like moving fast enough while avoiding hitting enemies on sight without getting hit once each round but don't worry about them crashing into any obstacle at all because every single boss has its own unique attack which makes fighting against baddies much easier thanks also having access not only physical attacks themselves - however many abilities exist outside those limited options since most items do have certain special effects too – check out our guide here
